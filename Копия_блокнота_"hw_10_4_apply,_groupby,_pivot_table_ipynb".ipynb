# %% [markdown]
# <a href="https://colab.research.google.com/github/marinamaer123/new_test/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22hw_10_4_apply%2C_groupby%2C_pivot_table_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/supermarket_sales.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df.groupby('Branch')['gross income'].sum()
#branch C has highest income.
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.groupby(['Branch','City'])['gross income'].sum().idxmax()
# Out:
# ('C', 'Naypyitaw')

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table(df, index = 'Branch', columns = 'Product line', values = 'Invoice ID', aggfunc = 'count')

# %%
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].idxmax()
#branch A has the biggest amount of invoices at Electronic accessories.
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %%
df.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total      Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715  1/5/2019  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1

# %% [markdown]
# #1. What type of customers have more invoices , who has higher gross income and in wnich group  average check is higher ?
# ###In case if members have better result to provide special offers for participation in membership.

# %%
df.groupby('Customer type').agg({'Invoice ID': 'count', 'gross income': 'sum','Total': 'mean'})
# Out:
#                Invoice ID  gross income       Total
# Customer type
# Member                501      7820.164  327.791305
# Normal                499      7559.205  318.122856

# %% [markdown]
# ######We investigated that members have potential for larger purchases what makes sense to evolve more customers into memebership.Also we can see that gross income is higher for members as well .Almost same amount of invoices but with the difference quality of them .
# #2.At which time by  hours we have minimum  invoices  ?To provide special offers for those hours.

# %%
df.Time.dtype
# Out:
# dtype('O')

# %%
df['hour'] = df['Time'].str.split(':').str[0].astype(int)

# %%
df.groupby('hour')['Invoice ID'].count()
# Out:
# hour
# 10    101
# 11     90
# 12     89
# 13    103
# 14     83
# 15    102
# 16     77
# 17     74
# 18     93
# 19    113
# 20     75
# Name: Invoice ID, dtype: int64

# %% [markdown]
# ###We can see small drop off points from 4 pm to 5 pm .During this time we can provide 'hot hours' discount program to get more customers at this time .

# %% [markdown]
# # 3. What product line have highest and minimal gross income by cities?To make right distirbution .

# %%
df.groupby(['City','Product line'])['gross income'].sum()
# Out:
# City       Product line
# Mandalay   Electronic accessories     811.9735
#            Fashion accessories        781.5865
#            Food and beverages         724.5185
#            Health and beauty          951.4600
#            Home and lifestyle         835.6745
#            Sports and travel          951.8190
# Naypyitaw  Electronic accessories     903.2845
#            Fashion accessories       1026.6700
#            Food and beverages        1131.7550
#            Health and beauty          791.2060
#            Home and lifestyle         661.6930
#            Sports and travel          750.5680
# Yangon     Electronic accessories     872.2435
#            Fashion accessories        777.7385
#            Food and beverages         817.2905
#            Health and beauty          599.8930
#            Home and lifestyle        1067.4855
#            Sports and travel          922.5095
# Name: gross income, dtype: float64

# %% [markdown]
# ### For Mandalay city Sports and travel and Health and beauty have highest gross income while food and baverages have lowest.We need to check the quality of these product line there and compare it to Naypyitaw because there income od this product line almost twice higher and it is highest gross income product line there.But in Naypyitaw we need to pay attention to Sports and travel section because it has lowest sales.In Yangon sales of Health and beauty low-selling so we need to compare quality of this product line to it to Mandalay.For a while top saling is Home and lifestyle in Yangon.
